# %%
import pandas as pd

# %%
s1 = pd.read_csv('marks.csv.txt').squeeze()
print(s1)

# %%
s2 = pd.read_csv('marks.csv.txt',usecols=['Student_Name','ML']).squeeze()
print(s2)

# %%
s3 = pd.read_excel('marks.xls.xlsx',usecols=['Student_Name','Python','SQL']).squeeze()
print(s3)
# Out:
#          Student_Name  Python  SQL
# 0        Aarav Sharma      85   92
# 1        Vivaan Patel      90   84
# 2        Aditya Verma      72   80
# 3        Vihaan Gupta      98   91
# 4           Arjun Rao      79   88
# 5         Sai Krishna      83   76
# 6         Reyansh Das      89   95
# 7         Aayan Joshi      74   70
# 8        Krishna Nair      88   82
# 9       Ishaan Mishra      81   89
# 10  Shaurya Choudhury      92   96
# 11      Aanya Singhal      87   85
# 12      Diya Kulkarni      80   79
# 13       Saanvi Reddy      95   97
# 14  Ananya Chatterjee      84   90
# 15       Khushi Mehta      75   73
# 16    Aadhya Tripathi      91   87
# 17        Pari Saxena      78   81
# 18     Ahana Banerjee      85   83
# 19      Anvi Deshmukh      94   88
# 20      Pranav Pillai      82   85
# 21       Devansh Shah      70   68
# 22     Rohan Malhotra      89   92
# 23     Tanishq Kapoor      76   80
# 24         Kabir Bhat      97   94
# 25        Rudra Joshi      83   86
# ...

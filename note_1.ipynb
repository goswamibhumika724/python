# %%
print('hello')
# Out:
# hello

# %%
print('i am learning AI machine learning data science')
# Out:
# i am learning AI machine learning data science

# %%
import numpy as np
arr1 = np.array([10,20,40,70,80,90])

# %%
print(arr1)
# Out:
# [10 20 40 70 80 90]

# %%
array = arr1 + 6
print(array)
# Out:
# [16 26 46 76 86 96]
